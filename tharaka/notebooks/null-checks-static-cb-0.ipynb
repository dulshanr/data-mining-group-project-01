# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import missingno as msno
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
static_cb = pd.read_csv('/kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_static_cb_0.csv')
static_cb.head()
# Out:
# /tmp/ipykernel_33/1503488160.py:1: DtypeWarning: Columns (1,2,3,4,7,45,46,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   static_cb = pd.read_csv('/kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_static_cb_0.csv')
#    case_id assignmentdate_238D assignmentdate_4527235D  \
# 0      357                 NaN                     NaN
# 1      381                 NaN                     NaN
# 2      388                 NaN                     NaN
# 3      405                 NaN                     NaN
# 4      409                 NaN                     NaN
#
#   assignmentdate_4955616D birthdate_574D  contractssum_5085716L  \
# 0                     NaN     1988-04-01                    NaN
# 1                     NaN     1973-11-01                    NaN
# 2                     NaN     1989-04-01                    NaN
# 3                     NaN     1974-03-01                    NaN
# 4                     NaN     1993-06-01                    NaN
#
#   dateofbirth_337D dateofbirth_342D  days120_123L  days180_256L  days30_165L  \
# 0              NaN              NaN           NaN           NaN          NaN
# 1              NaN              NaN           NaN           NaN          NaN
# 2       1989-04-01              NaN           6.0           8.0          2.0
# 3       1974-03-01              NaN           0.0           0.0          0.0
# 4       1993-06-01              NaN           2.0           3.0          0.0
#
#    days360_512L  days90_310L description_5085714M education_1103M  \
# 0           NaN          NaN             a55475b1        a55475b1
# 1           NaN          NaN             a55475b1        a55475b1
# 2          10.0          4.0             a55475b1        a55475b1
# 3           1.0          0.0             a55475b1        a55475b1
# 4           3.0          1.0             a55475b1        717ddd49
#
#   education_88M  firstquarter_103L  for3years_128L  for3years_504L  \
# 0      a55475b1                NaN             NaN             NaN
# 1      a55475b1                NaN             NaN             NaN
# 2      a55475b1                2.0             NaN             NaN
# 3      a55475b1                0.0             NaN             NaN
# 4      a55475b1                4.0             NaN             NaN
#
#    for3years_584L  formonth_118L  formonth_206L  formonth_535L  \
# 0             NaN            NaN            NaN            NaN
# 1             NaN            NaN            NaN            NaN
# 2             NaN            NaN            NaN            NaN
# 3             NaN            NaN            NaN            NaN
# 4             NaN            NaN            NaN            NaN
#
#    forquarter_1017L  forquarter_462L  forquarter_634L  fortoday_1092L  \
# 0               NaN              NaN              NaN             NaN
# 1               NaN              NaN              NaN             NaN
# 2               NaN              NaN              NaN             NaN
# 3               NaN              NaN              NaN             NaN
# 4               NaN              NaN              NaN             NaN
#
#    forweek_1077L  forweek_528L  forweek_601L  foryear_618L  foryear_818L  \
# 0            NaN           NaN           NaN           NaN           NaN
# 1            NaN           NaN           NaN           NaN           NaN
# 2            NaN           NaN           NaN           NaN           NaN
# 3            NaN           NaN           NaN           NaN           NaN
# 4            NaN           NaN           NaN           NaN           NaN
#
#    foryear_850L  fourthquarter_440L maritalst_385M maritalst_893M  \
# 0           NaN                 NaN       a55475b1       a55475b1
# 1           NaN                 NaN       a55475b1       a55475b1
# 2           NaN                 6.0       a55475b1       a55475b1
# 3           NaN                 4.0       a55475b1       a55475b1
# 4           NaN                 1.0       a7fcb6e5       a55475b1
#
#    numberofqueries_373L  pmtaverage_3A  pmtaverage_4527227A  \
# 0                   NaN            NaN                  NaN
# 1                   NaN            NaN                  NaN
# 2                  10.0            NaN                  NaN
# 3                   1.0            NaN                  NaN
# 4                   3.0            NaN                  NaN
#
#    pmtaverage_4955615A  pmtcount_4527229L  pmtcount_4955617L  pmtcount_693L  \
# 0                  NaN                NaN                NaN            NaN
# 1                  NaN                NaN                NaN            NaN
# 2                  NaN                NaN                NaN            NaN
# 3                  NaN                NaN                NaN            NaN
# 4                  NaN                NaN                NaN            NaN
#
#    pmtscount_423L  pmtssum_45A requesttype_4525192L responsedate_1012D  \
# 0             6.0    6301.4000                  NaN         2019-01-25
# 1             6.0    4019.6000                  NaN         2019-01-25
# 2             6.0   14548.0000                  NaN         2019-01-28
# 3             6.0   10498.2400                  NaN         2019-01-21
# 4             7.0    6344.8804                  NaN         2019-01-21
#
#   responsedate_4527233D responsedate_4917613D riskassesment_302T  \
# 0                   NaN                   NaN                NaN
# 1                   NaN                   NaN                NaN
# 2                   NaN                   NaN                NaN
# 3                   NaN                   NaN                NaN
# 4                   NaN                   NaN                NaN
#
#    riskassesment_940T  secondquarter_766L  thirdquarter_1082L
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 3.0                 5.0
# 3                 NaN                 2.0                 0.0
# 4                 NaN                 0.0                 4.0

# %%
msno.matrix(static_cb)
# Out:
# <Axes: >

# %%
static_cb.count()
# Out:
# case_id                    1500476
# assignmentdate_238D         136996
# assignmentdate_4527235D     114978
# assignmentdate_4955616D      71633
# birthdate_574D              607871
# contractssum_5085716L       157329
# dateofbirth_337D           1385691
# dateofbirth_342D             36500
# days120_123L               1385691
# days180_256L               1385691
# days30_165L                1385691
# days360_512L               1385691
# days90_310L                1385691
# description_5085714M       1500476
# education_1103M            1500476
# education_88M              1500476
# firstquarter_103L          1385691
# for3years_128L               36514
# for3years_504L               36514
# for3years_584L               36514
# formonth_118L                36514
# formonth_206L                36514
# formonth_535L                36514
# forquarter_1017L             36514
# forquarter_462L              36514
# forquarter_634L              36514
# fortoday_1092L               36514
# forweek_1077L                36514
# forweek_528L                 36514
# forweek_601L                 36514
# foryear_618L                 36514
# foryear_818L                 36514
# foryear_850L                 36514
# fourthquarter_440L         1385691
# maritalst_385M             1500476
# maritalst_893M             1500476
# numberofqueries_373L       1385691
# pmtaverage_3A               143589
# pmtaverage_4527227A         114978
# pmtaverage_4955615A          71845
# pmtcount_4527229L           114978
# pmtcount_4955617L            71845
# pmtcount_693L               146406
# pmtscount_423L              572638
# pmtssum_45A                 572638
# requesttype_4525192L        673264
# responsedate_1012D          720000
# responsedate_4527233D       660327
# responsedate_4917613D       224912
# riskassesment_302T           53559
# riskassesment_940T           53560
# secondquarter_766L         1385691
# thirdquarter_1082L         1385691
# dtype: int64

# %%
data_dic = pd.read_csv('/kaggle/input/home-credit-credit-risk-model-stability/feature_definitions.csv')
data_dic.head()
# Out:
#                   Variable                                        Description
# 0           actualdpd_943P  Days Past Due (DPD) of previous contract (actu...
# 1  actualdpdtolerance_344P                      DPD of client with tolerance.
# 2     addres_district_368M                  District of the person's address.
# 3         addres_role_871L                          Role of person's address.
# 4          addres_zip_823M                           Zip code of the address.

# %%
data_dic[data_dic['Variable'].isin(static_cb.columns)]
# Out:
#                     Variable  \
# 27       assignmentdate_238D
# 28   assignmentdate_4527235D
# 29   assignmentdate_4955616D
# 41            birthdate_574D
# 84     contractssum_5085716L
# 119         dateofbirth_337D
# 120         dateofbirth_342D
# 126             days120_123L
# 127             days180_256L
# 128              days30_165L
# 129             days360_512L
# 130              days90_310L
# 139     description_5085714M
# 159          education_1103M
# 161            education_88M
# 183        firstquarter_103L
# 184           for3years_128L
# 185           for3years_504L
# 186           for3years_584L
# 187            formonth_118L
# 188            formonth_206L
# 189            formonth_535L
# 190         forquarter_1017L
# 191          forquarter_462L
# 192          forquarter_634L
# 193           fortoday_1092L
# 194            forweek_1077L
# 195             forweek_528L
# 196             forweek_601L
# 197             foryear_618L
# 198             foryear_818L
# 199             foryear_850L
# 200       fourthquarter_440L
# 254           maritalst_385M
# 256           maritalst_893M
# 306     numberofqueries_373L
# 372            pmtaverage_3A
# 373      pmtaverage_4527227A
# 374      pmtaverage_4955615A
# 375        pmtcount_4527229L
# 376        pmtcount_4955617L
# 377            pmtcount_693L
# 394           pmtscount_423L
# 395              pmtssum_45A
# 419     requesttype_4525192L
# 425       responsedate_1012D
# 426    responsedate_4527233D
# 427    responsedate_4917613D
# 429       riskassesment_302T
# 430       riskassesment_940T
# 435       secondquarter_766L
# 449       thirdquarter_1082L
#
#                                            Description
# 27            Tax authority data - date of assignment.
# 28            Tax authority data - Date of assignment.
# 29                      Tax authority assignment date.
# 41        Client's date of birth (credit bureau data).
# 84   Total sum of values of contracts retrieved fro...
# 119                            Client's date of birth.
# 120                            Client's date of birth.
# 126  Number of credit bureau queries for the last 1...
# 127  Number of credit bureau queries for last 180 d...
# 128  Number of credit bureau queries for the last 3...
# 129  Number of Credit Bureau queries for last 360 d...
# 130  Number of credit bureau queries for the last 9...
# 139        Categorization of clients by credit bureau.
# 159  Level of education of the client provided by e...
# 161                     Education level of the client.
# 183  Number of results obtained from credit bureau ...
# 184  Number of rejected applications in the past 3 ...
# 185  Client's credit history data over the last thr...
# 186       Number of cancellations in the last 3 years.
# 187                   Number of rejections in a month.
# 188      Number of cancelations in the previous month.
# 189                 Credit history for the last month.
# 190  Number of cancellations recorded in the credit...
# 191  Number of credit applications that were reject...
# 192               Credit history for the last quarter.
# 193                 Client's credit history for today.
# 194           Number of cancelations in the last week.
# 195                  Credit history for the last week.
# 196  Number of rejected applications in the last week.
# 197  Number of application rejections in the previo...
# 198  Number of cancelations that occurred in last y...
# 199                  Credit history for the last year.
# 200               Number of results in fourth quarter.
# 254                      Marital status of the client.
# 256                       Marital status of the client
# 306                Number of queries to credit bureau.
# 372                         Average of tax deductions.
# 373                         Average of tax deductions.
# 374                         Average of tax deductions.
# 375                          Number of tax deductions.
# 376                          Number of tax deductions.
# 377                          Number of tax deductions.
# 394                  Number of tax deduction payments.
# 395              Sum of tax deductions for the client.
# 419                        Tax authority request type.
# 425                     Tax authority's response date.
# 426                     Tax authority's response date.
# 427                     Tax authority's response date.
# 429  Estimated probability that the client will def...
# 430             Estimate of client's creditworthiness.
# 435               Number of results in second quarter.
# 449                Number of results in third quarter.
