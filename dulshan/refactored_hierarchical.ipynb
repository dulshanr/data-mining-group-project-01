# %%
import pandas as pd
import numpy as np

# %%
heir_raw = pd.read_parquet('./heir_raw.parquet')
df_y_actual = pd.read_parquet('./actual.parquet')

# %%
# Dendogram for Heirarchical Clustering
import scipy.cluster.hierarchy as shc
from matplotlib import pyplot

pyplot.figure(figsize=(10, 7))  
pyplot.title("Dendrograms")  
dend = shc.dendrogram(shc.linkage(heir_raw, method='ward'))
pyplot.axhline(y=15000, color='r', linestyle='--')

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward') 
predicted_values = cluster.fit_predict(heir_raw)
# Out:
# C:\Users\Dulshan\PycharmProjects\jupyter\.venv\lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
df_pred = pd.DataFrame(predicted_values, columns=['pred'])

# %%
final_df = pd.concat([df_pred, df_y_actual], axis=1, join="inner")

# %%
final_df
# Out:
#        pred  actual
# 0         0       0
# 1         1       0
# 2         0       0
# 3         0       1
# 4         1       1
# ...     ...     ...
# 67186     1       1
# 67187     0       0
# 67188     1       0
# 67189     0       1
# 67190     0       1
#
# [67191 rows x 2 columns]

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
predicted = final_df['pred']
actual = final_df['actual']

# %%
# Calculating accuracy
accuracy = accuracy_score(actual, predicted)

# Calculating precision
precision = precision_score(actual, predicted, average='weighted')

# Calculating recall
recall = recall_score(actual, predicted, average='weighted')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# Accuracy: 0.5076275096367073
# Precision: 0.5076123115629723
# Recall: 0.5076275096367073

# %%
from sklearn.metrics import silhouette_score
silhouette_avg = silhouette_score(heir_raw, predicted)
print("Silhouette Score:", silhouette_avg)
# Out:
# Silhouette Score: 0.4939046507670186

# %%
heir_raw.reset_index(inplace=False)
# Out:
#          case_id     MONTH  WEEK_NUM  cntincpaycont9m_3716944L  \
# 0       105588.0  201901.0       2.0                  0.138437
# 1      2608648.0  201908.0      32.0                 -0.731513
# 2      2583138.0  201906.0      23.0                  0.660408
# 3      1358817.0  201905.0      17.0                 -0.731513
# 4      1314891.0  201903.0      11.0                  0.834398
# ...          ...       ...       ...                       ...
# 67186   214133.0  202003.0      61.0                  1.182378
# 67187   749026.0  201907.0      28.0                 -0.731513
# 67188  1770557.0  202002.0      56.0                  1.182378
# 67189    30218.0  201909.0      36.0                 -0.731513
# 67190   895178.0  201912.0      49.0                 -0.731513
#
#        cntpmts24_3658933L  commnoinclast6m_3546845L  eir_270L  \
# 0               -0.123999                       0.0  0.934709
# 1               -0.885906                       0.0  0.771123
# 2                2.288709                       0.0  0.771123
# 3               -0.758922                       0.0  0.825652
# 4                0.256955                       0.0  0.607537
# ...                   ...                       ...       ...
# 67186            0.256955                       0.0  0.934709
# 67187           -0.885906                       0.0  0.607537
# 67188            0.129970                       0.0  0.607537
# 67189           -0.885906                       0.0 -0.428507
# 67190           -0.885906                       0.0  0.934709
#
#        interestrate_311L  lastapprcredamount_781A  lastrejectcredamount_222A  \
# 0               0.894569                 2.095303                  -0.616854
# 1               0.728891                 0.115756                   0.600801
# 2               0.728891                 2.095303                  -0.089203
# 3               0.784117                -0.370647                  -0.464485
# 4               0.563213                -0.376868                  -0.616854
# ...                  ...                      ...                        ...
# 67186           0.894569                 1.360043                   0.194916
# 67187           0.563213                -0.732621                  -0.616854
# 67188           0.563213                -0.280153                  -0.616854
# 67189          -0.060213                -0.732621                   0.194916
# 67190           0.894569                -0.732621                  -0.616854
#
#        ...  disbursementtype_67L  isbidproduct_1095L  \
# 0      ...                   1.0                 0.0
# 1      ...                   1.0                 1.0
# 2      ...                   1.0                 1.0
# 3      ...                   2.0                 0.0
# 4      ...                   2.0                 0.0
# ...    ...                   ...                 ...
# 67186  ...                   1.0                 0.0
# 67187  ...                   2.0                 0.0
# 67188  ...                   2.0                 0.0
# 67189  ...                   0.0                 0.0
# 67190  ...                   2.0                 0.0
#
#        lastapprcommoditycat_1041M  lastapprcommoditytypec_5251766M  \
# 0                            33.0                             85.0
# 1                            33.0                             85.0
# 2                            33.0                             85.0
# 3                             6.0                             85.0
# 4                             6.0                             85.0
# ...                           ...                              ...
# 67186                        33.0                             85.0
# 67187                        33.0                             85.0
# 67188                        33.0                             85.0
# 67189                        33.0                             85.0
# 67190                        33.0                             85.0
#
#        lastcancelreason_561M  lastrejectcommoditycat_161M  \
# 0                       57.0                         35.0
# 1                       57.0                         35.0
# 2                       18.0                         35.0
# 3                       57.0                         29.0
# 4                       57.0                         35.0
# ...                      ...                          ...
# 67186                   52.0                         35.0
# 67187                   57.0                         35.0
# 67188                   57.0                         35.0
# 67189                   52.0                         35.0
# 67190                   57.0                         35.0
#
#        lastrejectcommodtypec_5251769M  lastrejectreason_759M  \
# 0                                84.0                   17.0
# 1                                84.0                   17.0
# 2                                84.0                   17.0
# 3                                84.0                   15.0
# 4                                84.0                   17.0
# ...                               ...                    ...
# 67186                            84.0                    7.0
# 67187                            84.0                   17.0
# 67188                            84.0                   17.0
# 67189                            84.0                    7.0
# 67190                            84.0                   17.0
#
#        lastrejectreasonclient_4145040M  previouscontdistrict_112M
# 0                                 10.0                      136.0
# 1                                 10.0                        8.0
# 2                                 10.0                      171.0
# 3                                  9.0                      168.0
# 4                                 10.0                       85.0
# ...                                ...                        ...
# 67186                              9.0                       25.0
# 67187                             10.0                      221.0
# 67188                             10.0                       35.0
# 67189                              9.0                      221.0
# 67190                             10.0                      221.0
#
# [67191 rows x 121 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
reduced_data = pca.fit_transform(heir_raw)
numped_arry = predicted.to_numpy()

# %%
plt.scatter(reduced_data[numped_arry == 0, 0], reduced_data[numped_arry == 0, 1], color='red', label='Class 0')
plt.scatter(reduced_data[numped_arry == 1, 0], reduced_data[numped_arry == 1, 1], color='blue', label='Class 1')
plt.title('PCA Visualization of Data Points (2D)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
from sklearn.metrics import rand_score, adjusted_rand_score

RI = rand_score(actual, predicted)
ARI = adjusted_rand_score(actual, predicted)

# %%
RI
# Out:
# 0.5001089179547198
